# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def implicit():
    from google.cloud import storage

    # If you don't specify credentials when constructing the client, the
    # client library will look for credentials in the environment.
    storage_client = storage.Client()

    # Make an authenticated API request
    buckets = list(storage_client.list_buckets())
    print(buckets)

# %%
import json

# %%
pip install -e git+https://github.com/SohierDane/BigQuery_Helper#egg=bq_helper
# Out:
# Obtaining bq_helper from git+https://github.com/SohierDane/BigQuery_Helper#egg=bq_helper
#   Updating c:\users\vaish\jupyter notebooks\soc_project\src\bq-helper clone
# Requirement already satisfied: pandas in c:\users\vaish\anaconda3\lib\site-packages (from bq_helper) (0.25.1)
# Requirement already satisfied: google-cloud-bigquery in c:\users\vaish\anaconda3\lib\site-packages (from bq_helper) (2.4.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\vaish\anaconda3\lib\site-packages (from pandas->bq_helper) (1.16.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\vaish\anaconda3\lib\site-packages (from pandas->bq_helper) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\vaish\anaconda3\lib\site-packages (from pandas->bq_helper) (2.8.0)
# Requirement already satisfied: google-resumable-media<2.0dev,>=0.6.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-cloud-bigquery->bq_helper) (1.1.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in c:\users\vaish\anaconda3\lib\site-packages (from google-cloud-bigquery->bq_helper) (1.4.3)
# Requirement already satisfied: six<2.0.0dev,>=1.13.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-cloud-bigquery->bq_helper) (1.15.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-cloud-bigquery->bq_helper) (3.14.0)
# Requirement already satisfied: proto-plus>=1.10.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-cloud-bigquery->bq_helper) (1.11.0)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.23.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-cloud-bigquery->bq_helper) (1.23.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0; python_version >= "3.5" in c:\users\vaish\anaconda3\lib\site-packages (from google-resumable-media<2.0dev,>=0.6.0->google-cloud-bigquery->bq_helper) (1.0.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (2.22.0)
# Requirement already satisfied: setuptools>=34.0.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (41.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (1.52.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (1.23.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0; extra == "grpc" in c:\users\vaish\anaconda3\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (1.33.2)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-crc32c<2.0dev,>=1.0; python_version >= "3.5"->google-resumable-media<2.0dev,>=0.6.0->google-cloud-bigquery->bq_helper) (1.12.3)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\vaish\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vaish\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\vaish\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\vaish\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (3.0.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\vaish\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (4.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in c:\users\vaish\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (4.0)
# Requirement already satisfied: pycparser in c:\users\vaish\anaconda3\lib\site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0; python_version >= "3.5"->google-resumable-media<2.0dev,>=0.6.0->google-cloud-bigquery->bq_helper) (2.19)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\vaish\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.23.0->google-cloud-bigquery->bq_helper) (0.4.8)
# Installing collected packages: bq-helper
#   Found existing installation: bq-helper 0.4.1
#     Uninstalling bq-helper-0.4.1:
#       Successfully uninstalled bq-helper-0.4.1
#   Running setup.py develop for bq-helper
# Successfully installed bq-helper
# Note: you may need to restart the kernel to use updated packages.
#   Running command git fetch -q --tags
#   Running command git reset --hard -q 8615a7f6c1663e7f2d48aa2b32c2dbcb600a440f

# %%
import bq_helper
import os
 # accessing bigQuery database
os.environ['GOOGLE_APPLICATION_CREDENTAILS'] = "C:\\Users\\vaish\\Downloads\\demand-forecasting-295923-06e5f0b0c6de.json"

# %%
# Opening JSON file 
f = open('C:\\Users\\vaish\\Downloads\\demand-forecasting-295923-06e5f0b0c6de.json',) 
  
# returns JSON object as  
# a dictionary 
data = json.load(f) 
  
# Iterating through the json 
# list 
print(data)
  
# Closing file 
f.close()
# Out:
# {'type': 'service_account', 'project_id': 'demand-forecasting-295923', 'private_key_id': '06e5f0b0c6de666d2046ccd87579c8ff14821b7c', 'private_key': '-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n', 'client_email': 'demand-forecasting@demand-forecasting-295923.iam.gserviceaccount.com', 'client_id': '118426031833497403932', 'auth_uri': 'https://accounts.google.com/o/oauth2/auth', 'token_uri': 'https://oauth2.googleapis.com/token', 'auth_provider_x509_cert_url': 'https://www.googleapis.com/oauth2/v1/certs', 'client_x509_cert_url': 'https://www.googleapis.com/robot/v1/metadata/x509/demand-forecasting%40demand-forecasting-295923.iam.gserviceaccount.com'}

# %%
stackoverflow= bq_helper.BigQueryHelper("bigquery-public-data","stackoverflow")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-6-792a19b8cca3> in <module>
# ----> 1 stackoverflow= bq_helper.BigQueryHelper("bigquery-public-data","stackoverflow")
#
# c:\users\vaish\jupyter notebooks\soc_project\src\bq-helper\bq_helper.py in __init__(self, active_project, dataset_name, max_wait_seconds)
#      23         self.dataset_name = dataset_name
#      24         self.max_wait_seconds = max_wait_seconds
# ---> 25         self.client = bigquery.Client()
#      26         self.__dataset_ref = self.client.dataset(self.dataset_name, project=self.project_name)
#      27         self.dataset = None
#
# ~\Anaconda3\lib\site-packages\google\cloud\bigquery\client.py in __init__(self, project, credentials, _http, location, default_query_job_config, client_info, client_options)
#     178             credentials=credentials,
#     179             client_options=client_options,
# --> 180             _http=_http,
#     181         )
#     182
#
# ~\Anaconda3\lib\site-packages\google\cloud\client.py in __init__(self, project, credentials, client_options, _http)
#     247
#     248     def __init__(self, project=None, credentials=None, client_options=None, _http=None):
# --> 249         _ClientProjectMixin.__init__(self, project=project)
#     250         Client.__init__(self, credentials=credentials, client_options=client_options, _http=_http)
#
# ~\Anaconda3\lib\site-packages\google\cloud\client.py in __init__(self, project)
#     199
#     200     def __init__(self, project=None):
# --> 201         project = self._determine_default(project)
#     202         if project is None:
#     203             raise EnvironmentError(
#
# ~\Anaconda3\lib\site-packages\google\cloud\client.py in _determine_default(project)
#     214     def _determine_default(project):
#     215         """Helper:  use default project detection."""
# --> 216         return _determine_default_project(project)
#     217
#     218
#
# ~\Anaconda3\lib\site-packages\google\cloud\_helpers.py in _determine_default_project(project)
#     184     """
#     185     if project is None:
# --> 186         _, project = google.auth.default()
#     187     return project
#     188
#
# ~\Anaconda3\lib\site-packages\google\auth\_default.py in default(scopes, request, quota_project_id)
#     354             return credentials, effective_project_id
#     355
# --> 356     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started

# %%
# %matplotlib inline
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt # graphs and charts
#import pandas_profiling # generating Profile Report

import sklearn
from sklearn.model_selection import train_test_split # data splitting
import statsmodels.api as sm
from sklearn import metrics
from sklearn.linear_model import LinearRegression # Linear model

#import wordcloud
from flask import Flask, render_template, request, json
import json
import pandas as pd

# %%
#!pip install google-cloud-bigquery

# %%
#%load_ext google.cloud.bigquery

# %% [markdown]
# # **Accessing the Dataset**
#    * Accessing the required dataset from BigQuery
#
# ### About '*bq_helper*'
#    * <p style='text-align: justify;'> bq_helper package simplifies common read-only tasks in BigQuery by dealing with object references and unpacking result objects into pandas dataframes.</p>
#    * <p style='text-align: justify;'> It currently only works here on Kaggle as it does not have any handling for the BigQuery authorization functions that Kaggle handles behind the scenes. </p>
#    * <p style='text-align: justify;'>bq_helper requires the creation of one BigQueryHelper object per dataset. Let's make one now. We'll need to pass it two arguments: </p>
#       1) The name of the BigQuery project, which on Kaggle should always be bigquery-public-data
#       2) The name of the dataset, which can be found in the dataset description

# %%
stackoverflow = bq_helper.BigQueryHelper("bigquery-public-data","stackoverflow")
#from google.cloud import bigquery

# Construct a BigQuery client object.
#stackoverflow = bigquery.Client()
# Out:
# Using Kaggle's public dataset BigQuery integration.

# %%
stackoverflow.list_tables()
# Out:
# ['badges',
#  'comments',
#  'post_history',
#  'post_links',
#  'posts_answers',
#  'posts_moderator_nomination',
#  'posts_orphaned_tag_wiki',
#  'posts_privilege_wiki',
#  'posts_questions',
#  'posts_tag_wiki',
#  'posts_tag_wiki_excerpt',
#  'posts_wiki_placeholder',
#  'stackoverflow_posts',
#  'tags',
#  'users',
#  'votes']

# %%
stackoverflow.head("posts_questions")
# Out:
#          id                                              title  \
# 0  63709718   Firebase members access to financial information
# 1  63528889  How do I collect each file into a different fi...
# 2  63592551  How to speed up image detecting using firebase...
# 3  63612900  Binding Passenger to Localhost in Apache Integ...
# 4  63646523  How can I create something like a custom recur...
#
#                                                 body accepted_answer_id  \
# 0  <p>If you grant a member of your team an owner...               None
# 1  <p>I have ts files, coffee files, js files, js...               None
# 2  <p>I am using firebase_ml_vision to detect fac...               None
# 3  <p>I have Passenger set up and running in inte...               None
# 4  <p>I want to create a PeriodicTask which execu...               None
#
#    answer_count  comment_count community_owned_date  \
# 0             0              0                 None
# 1             0              0                 None
# 2             0              0                 None
# 3             0              0                 None
# 4             0              0                 None
#
#                      creation_date favorite_count  \
# 0 2020-09-02 16:26:50.757000+00:00           None
# 1 2020-08-21 19:18:07.333000+00:00           None
# 2 2020-08-26 07:26:42.693000+00:00           None
# 3 2020-08-27 09:17:36.597000+00:00           None
# 4 2020-08-29 11:37:14.963000+00:00           None
#
#                 last_activity_date                   last_edit_date  \
# 0 2020-09-02 16:26:50.757000+00:00                              NaT
# 1 2020-08-21 19:18:07.333000+00:00                              NaT
# 2 2020-08-26 07:37:19.417000+00:00 2020-08-26 07:37:19.417000+00:00
# 3 2020-08-27 09:17:36.597000+00:00                              NaT
# 4 2020-08-29 11:37:14.963000+00:00                              NaT
#
#   last_editor_display_name  last_editor_user_id owner_display_name  \
# 0                     None                  NaN               None
# 1                     None                  NaN               None
# 2                     None           13240914.0               None
# 3                     None                  NaN               None
# 4                     None                  NaN               None
#
#    owner_user_id parent_id  post_type_id  score  \
# 0        5642414      None             1      0
# 1       14122219      None             1      0
# 2       13240914      None             1      0
# 3         454246      None             1      0
# 4        5474887      None             1      0
#
#                                                 tags  view_count
# 0                               firebase|permissions           1
# 1                                  webpack|webpack-4           2
# 2         flutter|dart|face-detection|firebase-mlkit           2
# 3                         passenger|passenger-apache           2
# 4  python-3.x|django-rest-framework|celery|django...           2

# %% [markdown]
# ## Tokenizing the tags from dataset:

# %%
## Tokenizing the tags from dataset:

# %%
app = Flask(__name__)

@app.route('/')
def home():
    return render_template('test.html')

@app.route('/test')
def test():
    return render_template('test.html')

@app.route('/filter', methods=['POST'])
def filter():
    query1 = """select tags from `bigquery-public-data.stackoverflow.posts_questions` LIMIT 100000"""
    df = stackoverflow.query_to_pandas(query1)
    llist = df['tags'].to_list()
    new_list = [i.split('|') for i in llist]
    flat_list = []
    for sublist in new_list:
        for item in sublist:
            flat_list.append(item)
    #new_list.append(i.split('|'))
    
    print(flat_list)

# %%
import re
#list_of_tags = stackoverflow.to_list('tags')
query1 = """select tags from `bigquery-public-data.stackoverflow.posts_questions` LIMIT 100000"""
df = stackoverflow.query_to_pandas(query1)
llist = df['tags'].to_list()
print(llist[0:10])
new_list = [i.split('|') for i in llist]
flat_list = []
for sublist in new_list:
    for item in sublist:
        flat_list.append(item)
    #new_list.append(i.split('|'))
print("=======================")
print(new_list[0:10])
print("++++++++++++++++")
print(flat_list[0:10])
#print(tags)
# Out:
# ['firebase|permissions', 'webpack|webpack-4', 'flutter|dart|face-detection|firebase-mlkit', 'passenger|passenger-apache', 'python-3.x|django-rest-framework|celery|django-celery', 'joomla', 'tabula-py', 'formula', 'r|mlp', 'plugins|tags|anchor']
# =======================
# [['firebase', 'permissions'], ['webpack', 'webpack-4'], ['flutter', 'dart', 'face-detection', 'firebase-mlkit'], ['passenger', 'passenger-apache'], ['python-3.x', 'django-rest-framework', 'celery', 'django-celery'], ['joomla'], ['tabula-py'], ['formula'], ['r', 'mlp'], ['plugins', 'tags', 'anchor']]
# ++++++++++++++++
# ['firebase', 'permissions', 'webpack', 'webpack-4', 'flutter', 'dart', 'face-detection', 'firebase-mlkit', 'passenger', 'passenger-apache']

# %%
stackoverflow.table_schema("posts_questions")
# Out:
#                         name       type      mode description
# 0                         id    INTEGER  NULLABLE        None
# 1                      title     STRING  NULLABLE        None
# 2                       body     STRING  NULLABLE        None
# 3         accepted_answer_id    INTEGER  NULLABLE        None
# 4               answer_count    INTEGER  NULLABLE        None
# 5              comment_count    INTEGER  NULLABLE        None
# 6       community_owned_date  TIMESTAMP  NULLABLE        None
# 7              creation_date  TIMESTAMP  NULLABLE        None
# 8             favorite_count    INTEGER  NULLABLE        None
# 9         last_activity_date  TIMESTAMP  NULLABLE        None
# 10            last_edit_date  TIMESTAMP  NULLABLE        None
# 11  last_editor_display_name     STRING  NULLABLE        None
# 12       last_editor_user_id    INTEGER  NULLABLE        None
# 13        owner_display_name     STRING  NULLABLE        None
# 14             owner_user_id    INTEGER  NULLABLE        None
# 15                 parent_id     STRING  NULLABLE        None
# 16              post_type_id    INTEGER  NULLABLE        None
# 17                     score    INTEGER  NULLABLE        None
# 18                      tags     STRING  NULLABLE        None
# 19                view_count    INTEGER  NULLABLE        None

# %% [markdown]
# ## Data Pre-processing :
# * Removing irrelevant data
# * Querying the year and the number of posts per year from the '*posts_questions*' table

# %% [markdown]
# ## Number of posts for first 100000 tags

# %% [markdown]
# # Current Trends:

# %%
query1posts  = """select EXTRACT(year FROM creation_date) AS year, COUNT(id) as posts
        from `bigquery-public-data.stackoverflow.posts_questions`
        where extract(year from creation_date) >= 2008 and extract(year from creation_date) < 2021
        group by year
        order by year
        """

postcnt = stackoverflow.query_to_pandas(query1posts)
print(postcnt)
# Out:
#     year    posts
# 0   2008    57924
# 1   2009   342540
# 2   2010   692208
# 3   2011  1192677
# 4   2012  1633858
# 5   2013  2046718
# 6   2014  2152753
# 7   2015  2206658
# 8   2016  2209585
# 9   2017  2125712
# 10  2018  1903069
# 11  2019  1886780
# 12  2020  1644173

# %% [markdown]
# ## Total number of Posts Per year between 2008 and current year 2020

# %%
queryx = """select EXTRACT(year FROM creation_date) AS year, COUNT(*) AS posts 
        from `bigquery-public-data.stackoverflow.posts_questions`
        where extract(year from creation_date) >= 2008 and extract(year from creation_date) < 2021
        group by year
        order by year
        """

PostsCount = stackoverflow.query_to_pandas(queryx)
print(queryx)
print(PostsCount)
# Out:
# select EXTRACT(year FROM creation_date) AS year, COUNT(*) AS posts
#         from `bigquery-public-data.stackoverflow.posts_questions`
#         where extract(year from creation_date) >= 2008 and extract(year from creation_date) < 2021
#         group by year
#         order by year
#
#     year    posts
# 0   2008    57924
# 1   2009   342540
# 2   2010   692208
# 3   2011  1192677
# 4   2012  1633858
# 5   2013  2046718
# 6   2014  2152753
# 7   2015  2206658
# 8   2016  2209585
# 9   2017  2125712
# 10  2018  1903069
# 11  2019  1886780
# 12  2020  1644173

# %%
querysample = "select EXTRACT(year FROM creation_date) AS year, COUNT(id) as posts from `bigquery-public-data.stackoverflow.posts_questions` where extract(year from creation_date) >=2009 and extract(year from creation_date) < 2021 and tags IN ('Hadoop','Spark','Hive') group by year order by year"

# %%
timeseries = stackoverflow.query_to_pandas(querysample)
timeseries
# Out:
# Empty DataFrame
# Columns: [year, posts]
# Index: []

# %%
def CurrentTrends1(dfall, labels = None, title="Current Trends", **kwargs):
    query1 = "select EXTRACT(year FROM creation_date) AS year, COUNT(id) as posts from `bigquery-public-data.stackoverflow.posts_questions` where extract(year from creation_date) >=2009 and extract(year from creation_date) < 2021 and tags like '%"
    query3 ="%' group by year order by year"
    df = []
    
    if labels==None:
        labels = dfall    #the keywords list
        
    l = len(dfall)
    ###### for every tag, execute the query separately
    for i in range(l):
        query2 = dfall[i]    # dfall = ['hadoop','spark','hive']
        query = query1+query2+query3
        Posts = stackoverflow.query_to_pandas(query)
        Posts['posts']= Posts['posts']*100/PostsCount.posts
        pd.to_numeric(Posts['year'])
        df.append(Posts)
    
    trend = pd.merge(df[0], df[1], how='inner', on = 'year')
    trend = trend.set_index('year')
    
    if(l>2):
        for i in range(2,l):
            trend = pd.merge(trend, df[i], how='inner', on = 'year')
            trend = trend.set_index('year')
    print(trend)
    curr_trendsjson = trend.to_json(orient="index")
    
    #parsed = json.loads(curr_result1)
    #json.dumps(parsed, indent=4)
    
    
    return curr_trendsjson
    
    
    '''
    trend.plot(kind='line')
    plt.xlabel('Year', fontsize=15)
    plt.ylabel('Posts %', fontsize=15)
    y_pos=[2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
    plt.xticks(y_pos,fontsize=8)
    plt.yticks(fontsize=8)
    plt.title(title)
    plt.legend(labels, loc=[1.0,0.5])
    plt.show()
    '''
    #print(trend)
    
    #print(Posts)

# %%
def CurrentTrends(dfall, labels = None, title="Current Trends", **kwargs):
    query1 = "select EXTRACT(year FROM creation_date) AS year, COUNT(id) as posts from `bigquery-public-data.stackoverflow.posts_questions` where extract(year from creation_date) >=2009 and extract(year from creation_date) < 2021 and tags like '%"
    query3 ="%' group by year order by year"
    df = []
    
    if labels==None:
        labels = dfall    #the keywords list
        
    l = len(dfall)
    ###### for every tag, execute the query separately
    for i in range(l):
        query2 = dfall[i]    # dfall = ['hadoop','spark','hive']
        query = query1+query2+query3
        Posts = stackoverflow.query_to_pandas(query)
        Posts['posts']= Posts['posts']*100/PostsCount.posts
        pd.to_numeric(Posts['year'])
        df.append(Posts)
        

    trend = pd.DataFrame(df[0])
    trend = trend.set_index('year')
    #print(trend)
    
    
    if(l>1):
        for i in range(1,l):
            trend = pd.merge(trend, df[i], how='inner', on = 'year')
            trend = trend.set_index('year')
    #print("trend", trend)
    curr_trendsjson = trend.to_json(orient="index")
    
    #parsed = json.loads(curr_result1)
    #json.dumps(parsed, indent=4)
    print(trend)
    
    return curr_trendsjson
    
    ''''
    
    trend.plot(kind='line')
    plt.xlabel('Year', fontsize=15)
    plt.ylabel('Posts %', fontsize=15)
    y_pos=[2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
    plt.xticks(y_pos,fontsize=8)
    plt.yticks(fontsize=8)
    plt.title(title)
    plt.legend(labels, loc=[1.0,0.5])
    plt.show()
    '''
   
    
    #print(Posts)

# %%
## For testing purposes: 
curr_trend = CurrentTrends(['hadoop'])
# Out:
#        posts_x    posts_y
# year
# 2009  0.122574  22.809198
# 2010  0.093420   8.045484
# 2011  0.153567   6.221396
# 2012  0.228142   5.590030
# 2013  0.302719   6.246136
# 2014  0.308250   6.052519
# 2015  0.350621   6.852900
# 2016  0.313370   7.867418
# 2017  0.261361   9.667426
# 2018  0.177070  10.941463
# 2019  0.126900  14.369316
# 2020  0.100383  14.127826

# %%
curr_trend      #json object for current trends
# Out:
# '{"2009":{"posts_x":0.1225744078,"posts_y":22.8091982598,"posts":0.1674608107},"2010":{"posts_x":0.0934197466,"posts_y":8.0454837391,"posts":0.0575115315},"2011":{"posts_x":0.153566558,"posts_y":6.221395881,"posts":0.0606754039},"2012":{"posts_x":0.228142238,"posts_y":5.5900298237,"posts":0.0700105729},"2013":{"posts_x":0.3027190857,"posts_y":6.2461364452,"posts":0.089297846},"2014":{"posts_x":0.3082495976,"posts_y":6.0525192039,"posts":0.1011863872},"2015":{"posts_x":0.3506208097,"posts_y":6.8528995198,"posts":0.1319705512},"2016":{"posts_x":0.3133698108,"posts_y":7.8674176062,"posts":0.1590640688},"2017":{"posts_x":0.2613612964,"posts_y":9.6674262361,"posts":0.1719779959},"2018":{"posts_x":0.1770700829,"posts_y":10.9414633779,"posts":0.1598052794},"2019":{"posts_x":0.1269002858,"posts_y":14.3693160889,"posts":0.1525956232},"2020":{"posts_x":0.1003826625,"posts_y":14.1278262437,"posts":0.1224838084}}'

# %%
def FutureTrends(dfall, Year = 2019, labels = None, title="Trends in Technologies in ", **kwargs):

    plt.figure(figsize=(20,10))
    
    query1 = "select EXTRACT(year FROM creation_date) AS year, COUNT(id) as posts from `bigquery-public-data.stackoverflow.posts_questions` where extract(year from creation_date) >=2009 and extract(year from creation_date) < 2019 and tags like '%"
    query3 ="%' group by year order by year"
    df = []
    l = len(dfall)
    
    if (labels==None):
        labels = dfall
        
    for i in range(l):
        query2 = dfall[i]
        query = query1+query2+query3
        Posts = stackoverflow.query_to_pandas(query)
        Posts['posts']= Posts['posts']*100/PostsCount.posts
        pd.to_numeric(Posts['year'])
        df.append(Posts)
        
        predict = []
    for d in df:
        year=d['year'].values.reshape(-1,1)
        posts=d['posts'].values.reshape(-1,1)
        reg=LinearRegression()
        X_train = year
        Y_train = posts
        X_test = [[Year]]
        reg.fit(X_train,Y_train)
        predictions = reg.predict(X_test)
        predict.append(predictions)
    #print(predict)
    
    trend2 = pd.DataFrame(columns = ['Technology','Posts %'])
    trend2['Technology'] = labels
    trend2['Posts %'] = predict
    print(trend2)
    return trend2

    '''
    x_pos = np.arange(len(trend2['Technology']))
    print(x_pos)
    plt.bar(x_pos,trend2['Posts %'])
    plt.xticks(x_pos, trend2['Technology'],fontsize=15)
    plt.yticks(fontsize=15)
    plt.xlabel('Technologies',fontsize=20)
    plt.ylabel('Posts Percentage',fontsize=20)
    plt.title(title+str(Year),fontsize=30)
    plt.show()
    '''

# %%
(FutureTrends(['spark','hive','python'],2021))
# Out:
#   Technology                 Posts %
# 0      spark  [[0.8720421327124086]]
# 1       hive  [[0.1815359206096545]]
# 2     python   [[5.227991737243656]]
#   Technology                 Posts %
# 0      spark  [[0.8720421327124086]]
# 1       hive  [[0.1815359206096545]]
# 2     python   [[5.227991737243656]]

# %%
stackoverflow.head("posts_questions")

query1 = """select creation_date, count(id) AS summ from `bigquery-public-data.stackoverflow.posts_questions` group by creation_date LIMIT 100000"""
timeseries = stackoverflow.query_to_pandas(query1)
timeseries
# Out:
#                          creation_date  summ
# 0     2020-03-17 14:37:05.993000+00:00     1
# 1     2020-03-24 10:28:30.153000+00:00     1
# 2     2020-03-12 15:06:53.673000+00:00     1
# 3     2020-03-20 08:58:44.243000+00:00     1
# 4     2020-04-01 12:36:28.873000+00:00     1
# ...                                ...   ...
# 99995 2012-02-22 10:40:33.557000+00:00     1
# 99996 2012-02-26 21:03:14.600000+00:00     1
# 99997 2012-02-17 22:14:31.140000+00:00     1
# 99998 2012-02-10 13:19:55.037000+00:00     1
# 99999 2012-02-22 20:51:55.127000+00:00     1
#
# [100000 rows x 2 columns]

# %%
query3 = """WITH historic_views AS (
  SELECT *, '201703' q
  FROM `fh-bigquery.stackoverflow_archive.201703_posts_questions` 
  UNION ALL
  SELECT *, '201706' q 
  FROM `fh-bigquery.stackoverflow_archive.201706_posts_questions` 
  UNION ALL
  SELECT *,  '201709' q 
  FROM `fh-bigquery.stackoverflow_archive.201709_posts_questions` 
  UNION ALL
  SELECT *, '201712' q 
  FROM `fh-bigquery.stackoverflow_archive.201712_posts_questions` 
  UNION ALL
  SELECT *, '201803' q 
  FROM `fh-bigquery.stackoverflow_archive.201803_posts_questions` 
  UNION ALL
  SELECT *, '201806' q 
  FROM `fh-bigquery.stackoverflow_archive.201806_posts_questions` 
), top_tags 

), views_per_tag AS (
  SELECT tag, COUNTIF(DATE(creation_date) BETWEEN DATE_SUB(PARSE_DATE('%Y%m',  q), INTERVAL 3 MONTH) AND PARSE_DATE('%Y%m',  q)) questions
    , SUM(view_count) views_cum, PARSE_DATE('%Y%m',  q) q
  FROM historic_views, UNNEST(SPLIT(tags, '|')) tag
  GROUP BY tag, q
), views_per_q AS (
  SELECT *, views_cum - LAG(views_cum, 1) OVER(PARTITION BY tag ORDER BY q) views
  FROM views_per_tag
), percents AS (
  SELECT *
    , 100*views/SUM(views) OVER(PARTITION BY q) views_percent
    , 100*questions/SUM(questions) OVER(PARTITION BY q) questions_percent
  FROM views_per_q
  WHERE views IS NOT null
  AND tag IN (SELECT value FROM top_tags)
)

SELECT *
FROM percents

"""

# %%
query3 = WITH historic_views AS (
    SELECT *, EXTRACT(data from creation_date) as PostedDate, from `bigquery-public-data.stackoverflow.posts_questions` 
    WHERE 
    
    
    
   """select EXTRACT(year FROM creation_date) AS year, COUNT(*) AS posts 
        from `bigquery-public-data.stackoverflow.posts_questions`
        where extract(year from creation_date) >= 2008 and extract(year from creation_date) < 2021
        group by year
        order by year
        """ 
    

  SELECT *, '201703' q
  FROM `fh-bigquery.stackoverflow_archive.201703_posts_questions` 
  UNION ALL
  SELECT *, '201706' q 
  FROM `fh-bigquery.stackoverflow_archive.201706_posts_questions` 
  UNION ALL
  SELECT *,  '201709' q 
  FROM `fh-bigquery.stackoverflow_archive.201709_posts_questions` 
  UNION ALL
  SELECT *, '201712' q 
  FROM `fh-bigquery.stackoverflow_archive.201712_posts_questions` 
  UNION ALL
  SELECT *, '201803' q 
  FROM `fh-bigquery.stackoverflow_archive.201803_posts_questions` 
  UNION ALL
  SELECT *, '201806' q 
  FROM `fh-bigquery.stackoverflow_archive.201806_posts_questions` 
), top_tags AS (
    SELECT value FROM UNNEST((
       SELECT APPROX_TOP_COUNT(tags, 5000)top  
       FROM `fh-bigquery.stackoverflow_archive.201803_posts_questions` 
       WHERE NOT tags LIKE '%|%'))
    WHERE count > 10
), views_per_tag AS (
  SELECT tag, COUNTIF(DATE(creation_date) BETWEEN DATE_SUB(PARSE_DATE('%Y%m',  q), INTERVAL 3 MONTH) AND PARSE_DATE('%Y%m',  q)) questions
    , SUM(view_count) views_cum, PARSE_DATE('%Y%m',  q) q
  FROM historic_views, UNNEST(SPLIT(tags, '|')) tag
  GROUP BY tag, q
), views_per_q AS (
  SELECT *, views_cum - LAG(views_cum, 1) OVER(PARTITION BY tag ORDER BY q) views
  FROM views_per_tag
), percents AS (
  SELECT *
    , 100*views/SUM(views) OVER(PARTITION BY q) views_percent
    , 100*questions/SUM(questions) OVER(PARTITION BY q) questions_percent
  FROM views_per_q
  WHERE views IS NOT null
  AND tag IN (SELECT value FROM top_tags)
)

SELECT *
FROM percents

"""
# Out:
#   File "<ipython-input-21-9c271f1c7a6b>", line 1
#     query3 = WITH historic_views AS (
#                                ^
# SyntaxError: invalid syntax

# %%
abc  = stackoverflow.query_to_pandas(query3)
print(abc[0:10000])
